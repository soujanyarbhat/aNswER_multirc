# %% [markdown]
# # **NER-based QA on MultiRC - Evaluation Notebook**
#
# Steps:
#
# Optional -
#
# Data transformation script - To convert MultiRC dataset into NER dataset (arg - input jsonl MultiRC file, creates a csv file in output path for NER QA)
#
# 1. Load DEV set (TEST set not publicly available for MultiRC)
#
# 2. Pre-processing
#
# 3. Load trained model
#
# 4. Prediction
#
# 5. Analysis

# %% [markdown]
# # Mount GDrive & Prepare Paths

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# Paths - Data, Model
PARENT_DIR = "/content/gdrive/My Drive/MultiRC_NER"
TRAINED_MODEL_DIR = PARENT_DIR + "/output/trained_v4"
DATA_PATH = PARENT_DIR + "/data/dev_v4.csv"
EVAL_PATH = PARENT_DIR + "/evaluations/results.txt"
PRED_PATH = PARENT_DIR + "/evaluations"

# %%
# !ls '/content/gdrive/My Drive/MultiRC_NER/data'
# Out:
# backup	dev_sample_v4.csv  dev_v4.csv  qa  train_v4.csv  vocab.txt

# %% [markdown]
# ## OPTIONAL - Preprocess the MultiRC QA data and convert into NER format

# %%
import json
import re
import os

INPUT_FILE = "/content/gdrive/My Drive/MultiRC_NER/data/qa/dev.json"
OUTPUT_FILE = "/content/gdrive/My Drive/MultiRC_NER/data/eval.csv"
DATA_PATH = OUTPUT_FILE

DELIMITER = ','
IDX = 1
INTERNAL_TAG = 'I'

# Initializing the file
file = open(INPUT_FILE)

# Loading the data
data = json.load(file)

#print(data['data'])

paragraphList = data['data']

if os.path.exists(OUTPUT_FILE):
    os.remove(OUTPUT_FILE)

# HEADERS
with open(OUTPUT_FILE,'a+') as file:
    file.write("ID"+DELIMITER+"TOKEN"+DELIMITER+"TAG\n")

# to convert the sentence into CSV cell format (word,tag)
def generateCSVCell(idx, sentence, ch):
    words = list()
    cell = ''
    if ' ' in sentence:
        words = sentence.split(' ')
        wordIdx = 1
        for word in words:
            if len(word.strip()) is not 0:
                if wordIdx == 1:
                    if "." in word or "?" in word:
                        pos = word.find(".")
                        if pos == -1:
                            pos = word.find("?")
                        cell = cell + str(idx) + DELIMITER + word[0:pos] + DELIMITER + ch + '\n'
                        cell = cell + str(idx) + DELIMITER + word[pos:] + DELIMITER + INTERNAL_TAG + '\n'
                    else:
                        cell = cell + str(idx) + DELIMITER + word + DELIMITER + ch + '\n'
                else:
                    if "." in word or "?" in word:
                        pos = word.find(".")
                        if pos == -1:
                            pos = word.find("?")
                        cell = cell + str(idx) + DELIMITER + word[0:pos] + DELIMITER + INTERNAL_TAG + '\n'
                        cell = cell + str(idx) + DELIMITER + word[pos:] + DELIMITER + INTERNAL_TAG + '\n'
                    else:
                        cell = cell + str(idx) + DELIMITER + word + DELIMITER + INTERNAL_TAG + '\n'
                wordIdx+=1
        return cell
    
    if "." in sentence:
        temp = ''
        pos = sentence.find(".")
        temp = temp + str(idx) + DELIMITER + sentence[0:pos] + DELIMITER + ch + '\n'
        temp = temp + str(idx) + DELIMITER + sentence[pos:] + DELIMITER + INTERNAL_TAG + '\n'
        return temp
        
    return str(idx) + DELIMITER + sentence + DELIMITER + ch + '\n'
    
# to remove the redundant tag and data represent in the text
def sentenceFormat(sentence):
    """ Need to change this to remove """
    sentence = sentence.replace('</b>','').replace('<b>','').replace('<br>','').replace(',','').replace('\\','').replace('"','')
    sentence = re.sub('Sent\s[0-9]*:', '', sentence)
    sentence = sentence.strip()
    return sentence



for paragraphs in paragraphList:
    
    paraInfo = paragraphs['paragraph']
    sentences = paraInfo['text'].split('<br><b>')
    questionList = paraInfo['questions']
    
    
    
    for questions in questionList:
        questionText = questions['question']
        sentences_used = questions['sentences_used']
        
        if "?" not in questionText:
            questionText = questionText + "?"
        
        print(IDX, " --- ", questionText)
        
        paraData=''
        for idx in range(0,len(sentences)):
            paraData = paraData + generateCSVCell(IDX, sentenceFormat(sentences[idx]), 'P')
        
        quesData = generateCSVCell(IDX, sentenceFormat(questionText), 'Q')
        
        answersList = questions['answers']
        ansData = ''
        
        for answers in answersList:
            """ Adding dot at the end of answer """
            answerText = answers['text'] + "."
            isAnswer = answers['isAnswer']
            if isAnswer:
                ansData = ansData + generateCSVCell(IDX, sentenceFormat(answerText), 'C')
            else:
                ansData = ansData + generateCSVCell(IDX, sentenceFormat(answerText), 'W')
        
        IDX += 1

        with open(OUTPUT_FILE,'a+') as file:
            file.write(quesData+ansData+paraData)
            #file.write("*****************************,****,******\n")
# Out:
# 1  ---  Who were the people that opposed Air New Zealand's decisions?
# 2  ---  What company did Air New Zealand collaborate with the make the new video?
# 3  ---  How many named models to appear in the video?
# 4  ---  How might Air New Zealand's video partner benefited from helping to make this video?
# 5  ---  How was the "Safety in Paradise" video received?
# 6  ---  Where was the "Safety in Paradise" video shot?
# 7  ---  Which airline teamed up with Sports Illustrated magazine in order to produce a safety video?
# 8  ---  What is the "paradise" they are talking about?
# 9  ---  Which company created "The world's most beautiful safety video"?
# 10  ---  Which women appeared in the "Safety in Paradise" safety video?
# 11  ---  Deborah Russel critiqued a video produced by what company?
# 12  ---  What kind of career does Christie Brinkley have?
# 13  ---  How many male models were featured in the current video?
# 14  ---  Where did Chuck find weapons?
# 15  ---  How many times does Chuck come across the cave where the voodoo curse was originally created?
# 16  ---  What happened after Jenny and Chuck fleed?
# 17  ---  What form of transportation does Jenny use to reach the remote jungle island years later?
# 18  ---  Who arms themselves against the zombies?
# 19  ---  Why is Jenny able to escape death by zombies?
# 20  ---  Who is stranded on the island?
# 21  ---  Where do the mercenaries go to protect themselves after encountering their first zombie?
# 22  ---  Why didn't Jenny get killed by a zombie?
# 23  ---  Who returns to the island with a group of mercenaries?
# 24  ---  Who is given a charm by her mother?
# 25  ---  What are the deads called who feed on the living in retribution?
# 26  ---  Who kills the local priest?
# 27  ---  What did the judge tell Mr. Thorndike about the law?
# 28  ---  Who did the judge send to summon Mr. Thorndike?
# 29  ---  How did Mr. Thorndike feel when the judgment was rendered for Spear?
# 30  ---  Who told Mr. Thorndike he had done well?
# 31  ---  What does the judge say about the law?
# 32  ---  Who thanked Mr. Thorndike for coming that day?
# 33  ---  What did the judge personally tell Mr. Thorndike about himself?
# 34  ---  What was the beginning of the judge's speech mainly about?
# 35  ---  Who did Mr. Thorndike credit with getting Spear his liberty?
# 36  ---  Why did Mr. Thorndike feel a twinge of disappointment?
# 37  ---  Who did Mr. Thorndike want to help?
# 38  ---  How did Mr. Thorndike feel about the judge making his speech in regards to him?
# 39  ---  What was the judges result and did it please or displease Mr. Thorndike?
# 40  ---  Why did Mr. Thorndike feel his morning had been wasted?
# 41  ---  Why is the law just and not vindictive?
# 42  ---  Why did the judge loudly thank Mr. Thorndike for coming?
# 43  ---  What happens to a leaf as it falls?
# 44  ---  What happens to leaves in autumn in many parts of the world?
# 45  ---  What is an example of potential energy?
# 46  ---  How does potential energy exist and change?
# 47  ---  What kind of energy do leaves have while still on the trees?
# 48  ---  What happens to trees in autumn?
# 49  ---  What does the youngest son set on the table?
# 50  ---  What makes the youngest son different from his brothers?
# 51  ---  Who appears to be older, the woman or the man?
# 52  ---  Is the age difference between the man and woman sitting in front of the stove more or less than 10 years?
# 53  ---  What did the man and the woman sit over?
# 54  ---  Who has a scar across one of his hands?
# 55  ---  Who has a scar on his hand?
# 56  ---  Who served the stew?
# 57  ---  How many people are known to be in the house?
# 58  ---  Whose religious doctrines were those of the Low Church?
# 59  ---  Who was afraid of the world?
# 60  ---  Who was as superstitious as any self-flagellated nun?
# 61  ---  After the Osprey resumed flights in 2002 how long did it take for the Air Force to begin using the aircraft?
# 62  ---  What reasons might have caused the Osprey to be scrapped?
# 63  ---  How many crew members were injured in the crash of an Osprey aircraft on Wednesday?
# 64  ---  The crash that left five injured occurred at what time?
# 65  ---  Did the Marines or the Air Force use the Osprey first?
# 66  ---  Is it true that the most recent Osprey crash in Florida the most fatal Osprey crash?
# 67  ---  Amy Nicholson said the crash that occurred at 6:45pm happened where?
# 68  ---  How many people have died from the crash in Navarre, FL and in Arizona combined?
# 69  ---  What states has the Osprey crashed in?
# 70  ---  In how many states have Osprey crashes resulted in deaths according to the article?
# 71  ---  How long did it take the Air Force to use Ospreys after the Marines deployed them in Iraq?
# 72  ---  The tilt-rotor aircraft was assigned to what Wing in the Air Force?
# 73  ---  From the time the Army began developing the Osprey in 1982 to when the Army first used it, how much money was spent in development?
# 74  ---  When was the Osprey operations halted and restarted?
# 75  ---  When the Marines deployed the Osprey, how long had it been in development?
# 76  ---  When was the CV-22 budget called into question and what is the overall development total?
# 77  ---  How many years passed between the beginning of Osprey development and the fatal Osprey crash in Virginia?
# 78  ---  What branches of the armed forces use Ospreys?
# 79  ---  Was this the first accident an Osprey has had?
# 80  ---  How many were injured in the Hurlburt Field crash and from what unit?
# 81  ---  How many crashes was the CV-22 involved in?
# 82  ---  Where was Gabriel García Márquez born and when did he win the Nobel Prize?
# 83  ---  Whose speedy recover did Mexican President Enrique Peña wish on Twitter?
# 84  ---  What are the antibiotics administered to García Márquez supposed to treat?
# 85  ---  How many years after the novel "One Hundred Years of Solitude" was written did Gabo get a Nobel Prize?
# 86  ---  What is Gabriel García Márquez known for?
# 87  ---  Who said, "I wish you a speedy recovery."?
# 251  ---  Who is the doctor's attorney?
# 252  ---  Who published an accusation and who denied it?
# 253  ---  Which US agencies were involved in the Menendez scandal?
# 254  ---  Why was there yellow tape around the doctor's office?
# 255  ---  Why are there no official details about what the authorities were looking for?
# 256  ---  Doctor Melgen's office was raided as a result of which publication's article and the resulting investigation?
# 257  ---  .What is Menendez suspected of doing when he flew on Melgen's private jet?
# 258  ---  Why do men have a hands off policy when it comes to black women's hair?
# 259  ---  Why did Chris Rock begin looking into black women's hair?
# 260  ---  Which women do not allow men to touch their hair, according to Chris Rock?
# 261  ---  Chris Rock's research found out that Women spend too much time and money on what?
# 262  ---  Which Emmy-winning comedian claims that men are conditioned to not touch a black woman's hair?
# 263  ---  Whose daily activities, wallets, self-esteem , and even sex lives is affected by $9 billion industry, that Chris Rock discovered?
# 264  ---  What is the $9 million industry that affects the lives of black women?
# 265  ---  What did Chris Rock's carpool ride help him discover?
# 266  ---  Chris Rock said whenever he was with Asian, Puerto Rican, or white girl, his hand would be in particular part of those women's body. What was it?
# 267  ---  Why can't you touch a black woman's hair?
# 268  ---  Who is Chris Rock?
# 269  ---  Why did Chris Rock not make a big deal about his daughter's hair comments?
# 270  ---  How did Chris Rock describe his daughter's friend, who were sitting in the car with his daughter?
# 271  ---  What convinced Chris Rock to become a hair expert?
# 272  ---  Why does Sunita's professor deny her access to records on Sanjay Singhania?
# 273  ---  When Sunita begins to investigate, what does she initially learn?
# 274  ---  Why did Sanjay murdered a man?
# 275  ---  Why does Sanjay use a system of photographs, notes, and tattoos on his body?
# 276  ---  Why is Ghajini considered the main target of Sanjay?
# 277  ---  What action is misinterpreted as romantic one by the owner of Kalpana's firm?
# 278  ---  What reveals that Sanjay has anterograde amnesia?
# 279  ---  Who denies Sunita access to Sanjay's records, who is reported to have anterograde amnesia, because they are under criminal investigation?
# 280  ---  Every 15 minutes, Sanjay goes through what process, Which frustrates his attempts to avenge the death of his sweetheart?
# 281  ---  Why does Sunita's professor deny access to Sanjay's records?
# 282  ---  Which person investigates the case of Sanjay Singhania?
# 283  ---  Why is Sanjay using a system of photographs, notes, and tattoos on his body and killing people systematically?
# 284  ---  Sanjay is first seen doing what, which he memorializes with a Polaroid picture?
# 285  ---  The writers of which Association are said to have elevated the standard of Base Ball over the past 25 years?
# 286  ---  Is any argument required to prove that the standard of Base Ball has steadily been elevated?
# 287  ---  What characteristics of the pastime of baseball has been repressed?
# 288  ---  Has repression of the tendency to win by any means raised or lowered the morale of Base Ball?
# 289  ---  Which sport had a tendency to win by any means, which was later repressed?
# 290  ---  Why is it acceptable for the Southern Association to lack an organized membership?
# 291  ---  What does Martha hang on a silver refrigerator?
# 292  ---  Who is included in the picture that Lucy drew?
# 293  ---  What colors are definitely used in the picture Lucy drew?
# 294  ---  What does Lucy draw while sitting at the kitchen table?
# 295  ---  Who says "woof" and wants to play fetch?
# 296  ---  Who giggles and wished a bird could play fetch?
# 297  ---  Does Lucy have any brothers or sisters?
# 298  ---  What does Martha put on the silver refrigerator?
# 350  ---  Who were probably the ancestors of the Gododdin?
# 351  ---  What languages were spoken in old time Scotland that are listed in the article?
# 352  ---  Where is the city of Edinburgh located? How long has the civilization been around?
# 353  ---  What do we know about the Votadini?
# 354  ---  Who made the cuts to the LSEO and how did it manage to survive?
# 355  ---  What amount did the Oxley foundation donate and what was it used for?
# 356  ---  What agency helps more than 12,000 children a year?
# 357  ---  The Oxley Foundation donated $200,000 to expand a client hot line in whose honor?
# 358  ---  What phrase is etched on our U.S. Supreme Court building?
# 359  ---  Who are the Majority clients of LSEO?
# 360  ---  What are measures of speed?
# 361  ---  How does one determine speed?
# 362  ---  What is speed?
# 363  ---  How do US speed measurement and those used by a scientist differ?
# 364  ---  What is the formula for speed?
# 365  ---  How do you calculate speed in the U.S.?
# 366  ---  What two things do you need to know to determine speed?
# 367  ---  How is speed calculated?
# 368  ---  If your family took a car trip what information would you need to determine the average speed you traveled?
# 369  ---  What is the unit for speed and who uses it?
# 370  ---  How do you determine speed?
# 371  ---  How would the speed of a trip covering 120 miles and taking 3 hours be calculated?
# 372  ---  What are two units of speed?
# 373  ---  What are some different measurements to represent the speed of a car?
# 374  ---  What two different units of measure can be used to express speed?
# 375  ---  What brought the great wealth during Spain's 100 years Golden Age?
# 376  ---  Spain flourished under whose leadership?
# 377  ---  What event occurred that gave Charles V the undeniable message that he needed to pay more attention to his Spanish constituency?
# 378  ---  What problem did Charles face when he took the throne?
# 379  ---  The retinue of which Spanish monarch constituted of Burgundian and Flemish nobles?
# 380  ---  What changes did Spain undergo during the Golden Age reign of Ferdinand and Isabella?
# 381  ---  Who were the monarchs during the Golden Age of Spain?
# 382  ---  What was the outcome of the revolt against Charles V?
# 383  ---  Who are the grandparents of Charles I?
# 384  ---  Why were the Spanish people unhappy with Ferdinand and Isabella's grandson, Charles V?
# 385  ---  Who packed his retinue with Burgundian and Flemish nobles?
# 386  ---  Where Charles V was born?
# 387  ---  A revolt of the comuneros in Madrid happened under whose reign?
# 388  ---  Who were the royal pair that presided over the final conquest over the Moors and discovery of the New World?
# 389  ---  In what year Ferdinand and Isabella started to govern Spain?
# 390  ---  Who were the grandparents of the individual that assumed the throne in 1516?
# 391  ---  What forced Charles V to pay more attention to Spanish constituency?
# 392  ---  What title a grandson of Charles I inherited after arrival to Spain?
# 393  ---  What happens when your LEGO parts get mixed up?
# 394  ---  What do you call the process of sorting things by size and shape?
# 395  ---  Why is it fortunate that you sister just made a simple mixture?
# 396  ---  Why do you have to sort your LEGOs and put them in the tray?
# 397  ---  What is a simple mixture?
# 398  ---  What would be an irreversible mixture?
# 399  ---  What could your sister have done to cause a chemical change in the LEGOS?
# 400  ---  Tossing the LEGOs in the fireplace would have cause what type of change?
# 401  ---  In this passage, what needs sorted by size and shape?
# 402  ---  What is a mixture?
# 403  ---  Why are the Legos mixing reversible?
# 404  ---  What kind of change would have happened if your sister had thrown your LEGOs into the fireplace?
# 405  ---  In this passage, who created the mixture?
# 406  ---  What do you have to put back into the original categories?
# 407  ---  What your sister created, what is it called?
# 517  ---  Why will she be out of funds?
# 518  ---  What did Mintie use the "Use Your Life Award" on?
# 519  ---  How much money did go to the recipients?
# 520  ---  What did Alexander do when he learned that Cleitus, King of Illyria and King Glaukias of the Taulanti were in open revolt against his authority?
# 521  ---  What places did Alexander conquer?
# 522  ---  What two groups did Alexander defeat in order to secure the northern frontier?
# 523  ---  Did Alexander begin his Asian campaign before his defeat of Thebes?
# 524  ---  Did Alexander set out to secure his northern fronts and was he able to accomplish this goal?
# 525  ---  Who is Alexander's army called?
# 526  ---  What southern groups rebelled during Alexander's northern campaign?
# 527  ---  What was Alexander's immediate response when Thebes and Athens rebelled?
# 528  ---  Where in Greece are Thebes and Athens located?
# 529  ---  Were Cleitus and Glaukias killed in battle against Alexander's forces?
# 530  ---  How did the Thebans rebel against Alexander?
# 531  ---  What causes Ralph to bite the flight attendant?
# 532  ---  People head back to the plane to get what?
# 533  ---  Where is Ralph contained after he is bitten by a hamster?
# 534  ---  What was the original destination of the plane, and where did it land?
# 535  ---  Did the plane containing a lab rat land in Las Vegas?
# 536  ---  Was the plane allowed to approach the gate, why or why not?
# 537  ---  Who does Ralph bite after he becomes violent?
# 538  ---  Why was it important that Durer wrote about the price of prints in his diary?
# 539  ---  What was more beautiful than miracles, according to Durer?
# 540  ---  Why did Durer set out on the journey?
# 541  ---  The transfer of thermal energy in a fluid is called?
# 542  ---  Waves that transfer thermal energy through empty space are called?
# 543  ---  Can convection travel thorough empty space?
# 544  ---  What is radiation and how does it move?
# 545  ---  Are thermal insulators and thermal conductors both good conductors of heat?
# 546  ---  What is it called when thermal energy is transferred between 2 objects that are touching?
# 547  ---  What does conduction take place between?
# 548  ---  During Convection, which direction do the particles in the move?
# 549  ---  What is an example of radiant heat?
# 550  ---  Does the fluid in convection need to be a liquid?
# 551  ---  What is the difference between a thermal conductor and a thermal insulator?
# 552  ---  What is the process where particles move within and fluid and transfer thermal energy?
# 553  ---  According to this passage, waves that can move through empty space and transfer thermal energy are a part of what term?
# 554  ---  How do particles within a fluid move?
# 555  ---  What occurs as particles move within a fluid?
# 556  ---  In order for Convection to happen, should you use a conductor or an insulator?
# 557  ---  Has any mob violence occurred in Raikia?
# 558  ---  Who is India's federal government calling upon to end the conflicts?
# 559  ---  In which Indian state is Raikia located?
# 560  ---  How many people have died in Orissa due to Hindu-Christian violence?
# 561  ---  What is the name of the bay that borders the state in which a group attacked a church?
# 562  ---  What has India's federal government called upon Orissa state to do to control the conflicts?
# 563  ---  Do any tribal people live in the same state as the Hindu man who was killed?
# 564  ---  At least how many civilians have died in Orissa state this month in the Hindu-Christian violence?
# 565  ---  When was Mr. Petit released?
# 566  ---  Was the number of estimated employees protesting greater or lesser than the number of employees the executives were proposing to lay off?
# 567  ---  What building were the four captives inside on Tuesday?
# 568  ---  Provide the full name of one of the hostages?
# 569  ---  What company does Nicolas Polutnik work for?
# 570  ---  What is the news network reporting on the incident?
# 571  ---  Have any executives from the Caterpillar factory been hurt by the workers so far?
# 572  ---  How many times have French workers blockaded managers in their offices to demand negotiations over proposed layoffs?
# 866  ---  How many trips has Dennis Rodman made to North Korea in under 12 months?
# 867  ---  Where has Dennis Rodman gone 4 times in one year?
# 868  ---  What was Dennis Rodman's response when asked about his trip in regards to US detainee in North Korea?
# 869  ---  What animal was Kim Jong Un's uncle rumored to have been feed to?
# 870  ---  In addition to parking, how else will the new building help the non-profit agencies?
# 871  ---  What two areas of the building will all five agencies be sharing?
# 872  ---  What is the address of the new legal center that five Salt Lake legal organizations have purchased?
# 873  ---  Who were the previous owners of the building who moved out due to their business needing more space?
# 874  ---  What five groups work under the "And Justice For All" project?
# 875  ---  How is timber a renewable energy?
# 876  ---  What renewable resource can be affect by water pollution and overuse?
# 877  ---  What renewable resource can be replanted?
# 878  ---  What is an example of polluting resources?
# 879  ---  What is a renewable resource that we will never run out of?
# 880  ---  How are fish a renewable resource?
# 881  ---  What is an example of a renewable resource that can be polluted?
# 882  ---  What are some renewable resources?
# 883  ---  What are some examples of renewable resources?
# 884  ---  How can we overuse resources that should be renewable?
# 885  ---  What major event made the country of Spain so eager to capitalize on mass tourism?
# 886  ---  Which king brought democracy to Spain and was democracy successful?
# 887  ---  Why was there not very high tourism in Spain during Franco's regime and what happened that allow tourism to increase?
# 888  ---  Why was Spain so isolated and what event happened that allowed Mallorca and Menorca to see explosions in tourism?
# 889  ---  Why did a new emphasis on quality and on safeguarding the environment take root in Spain in the late 1990s?
# 890  ---  When did tourism in Spain explode into an annual southern migration?
# 891  ---  When did Spain begin to expand tourism and what was the impact on Spain?
# 892  ---  What year did Spain join the European Community (now European Union) and what effects did it have (1 positive and 1 negative)?
# 893  ---  Who had an intimidating effect on Little Masters for large engravings?
# 894  ---  Who was not intimidated by Durer in producing large engravings?
# 895  ---  Who is the artist with the longest name that was influenced by Durer to use the printmaking medium?
# 896  ---  Which organization holds remembrance for Durer in the winter holiday season?
# 897  ---  When the narrator arrived at the headquarters, approximately how many men were present?
# 898  ---  The area to where the Indians had retreated, where in proximity to Van Bremer's ranch?
# 899  ---  Where were the volunteers under Captains O.C. Applegate and Kelly to be concentrated once under the command of General Wheaten?
# 900  ---  Where did both strangers meet?
# 901  ---  Who are the two that Guty and Bruno are planning to murder?
# 902  ---  Why did Guy feel comfortable about telling Bruno about this murder plan?
# 903  ---  Why does the amateur tennis star Guy Haines want to divorce his wife Mirriam?
# 904  ---  What are the things given by Bruno to kill his father?
# 905  ---  Why does tennis star want to divorce his wife?
# 906  ---  What do Bruno send Guy with?
# 907  ---  When did Guy's problems begin?
# 908  ---  Which item did Guy leave behind that Bruno used against Miriam?
# 909  ---  The guy hurriedly leaves the compartment but leaves Bruno thinking he has agreed to the deal. what does he accidentally leave behind?
# 910  ---  Where did Bruno lose his cigarette lighter?
# 911  ---  What is the range and strength of gravity?
# 912  ---  What is gravity in charge of?
# 913  ---  What is gravity's role in space?
# 914  ---  How is gravity a special force?
# 915  ---  Why is gravity special?
# 916  ---  How does gravity work on far away objects?
# 917  ---  Who said that "one of the nation's most fundamental responsibilities is to protect its citizens from terrorist attacks."?
# 918  ---  What did the FBI's assistant director for counterterrorism believed the Justice Department wanted the FBI to do?
# 919  ---  Did the budget guidance issued on May 10 support the FBI assistant director for counterterrorism's belief regarding the Justice Department's goals for the FBI?
# 920  ---  When was the budget guidance highlighting gun crimes, narcotics trafficking, and civil rights as priorities issued?
# 921  ---  How did Ashcroft want to reform FBI?
# 922  ---  Former senator of which state wanted to reform FBI?
# 923  ---  What daily brief did the attorney general not receive?
# 924  ---  On what date was the budget guidance issued that highlighted gun crimes, narcotics trafficking, and civil rights as priorities?
# 925  ---  Who are John Ashcroft and Dale Watson?
# 926  ---  Who testified at a congressional hearing that, "one of the nation's most fundamental responsibilities is to protect its citizens from terrorist attacks"?
# 927  ---  Did the budget guidance issued on May 10 reflect consideration of the attorney general's congressional hearing testimony concerning federal efforts to combat terrorism?
# 928  ---  Who are the characters in this story?
# 929  ---  What two thinks does Emery fail to notice?
# 930  ---  Where do Emery and Allanah have sex?
# 931  ---  What happens at the restaurant?
# 932  ---  Who follows Emery and Allanah as he gives her a ride to work?
# 933  ---  Why did Thorndike touch Andrews' sleeve?
# 934  ---  Who sits down after Andrew whispers "Sit down"?
# 935  ---  What did his sponsor whisper?
# 936  ---  The man known as Arnold Thorndike was permitted to sit as an equal among police-court lawyers because of whom?
# 937  ---  What did the man who abandoned his point to in the beginning?
# 938  ---  Why was Arnold tolerated among the police-court lawyers?
# 939  ---  Was he tolerated because of his sponsor?
# 940  ---  Andrews said the oak chairs were reserved for whom?
# 941  ---  Why did Mr. Andrews point toward the chair?
# 942  ---  Was Usama Asmurai one of Bin Laden's subordinates?
# 943  ---  Did Bin Laden stop delivering diatribes to United States after he arrived to Sudan?
# 944  ---  Was Bin Laden the only terrorist leader?
# 945  ---   Bin Laden delivered diatribes in what two locations?
# 946  ---   Bin Laden's Fatwa was released in what year and contained wording that was originally released by what group four years earlier?
# 947  ---  What was the names and locations of two peers of bin Ladin?
# 948  ---  Name the country where US troops where deployed and the city where al Qaeda set two bombs.?
# 949  ---  Who is  Bin Laden referring to when he refers to "the head of the snake"?
# 950  ---  Where did  Bin Laden go after he left Saudi Arabia?
# 951  ---  How did AL Qaeda leaders address U.S. forces' arrival in Somalia?
# 952  ---  How did  Bin Laden's agenda differ from his peers?
# 953  ---  Who were considered Bin Laden's peers?

# %% [markdown]
# # Pre-processing NER data

# %% [markdown]
# **Requirements**

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# !pip install seqeval
# !pip install transformers

import pandas as pd
import math
import numpy as np
from seqeval.metrics import f1_score
from seqeval.metrics import classification_report,accuracy_score,f1_score
import torch.nn.functional as F

import torch
import os
from tqdm import tqdm,trange
from torch.optim import Adam
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler
from keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split
from transformers import BertTokenizer, BertConfig
from transformers import BertForTokenClassification, AdamW
# Out:
# Requirement already satisfied: seqeval in /usr/local/lib/python3.6/dist-packages (0.0.12)
# Requirement already satisfied: Keras>=2.2.4 in /usr/local/lib/python3.6/dist-packages (from seqeval) (2.3.1)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.6/dist-packages (from seqeval) (1.18.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from Keras>=2.2.4->seqeval) (3.13)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from Keras>=2.2.4->seqeval) (1.1.0)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from Keras>=2.2.4->seqeval) (1.4.1)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from Keras>=2.2.4->seqeval) (1.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from Keras>=2.2.4->seqeval) (2.10.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from Keras>=2.2.4->seqeval) (1.12.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.6/dist-packages (2.8.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from transformers) (1.18.3)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.6/dist-packages (from transformers) (0.0.41)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.6/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.6/dist-packages (from transformers) (0.1.86)
# Requirement already satisfied: dataclasses; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from transformers) (0.7)
# Requirement already satisfied: tokenizers==0.5.2 in /usr/local/lib/python3.6/dist-packages (from transformers) (0.5.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.6/dist-packages (from transformers) (3.0.12)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.6/dist-packages (from transformers) (4.38.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.6/dist-packages (from transformers) (1.12.47)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (1.12.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (0.14.1)
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (2.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (2020.4.5.1)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from boto3->transformers) (0.3.3)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.6/dist-packages (from boto3->transformers) (0.9.5)
# Requirement already satisfied: botocore<1.16.0,>=1.15.47 in /usr/local/lib/python3.6/dist-packages (from boto3->transformers) (1.15.47)
# Requirement already satisfied: docutils<0.16,>=0.10 in /usr/local/lib/python3.6/dist-packages (from botocore<1.16.0,>=1.15.47->boto3->transformers) (0.15.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.6/dist-packages (from botocore<1.16.0,>=1.15.47->boto3->transformers) (2.8.1)
# Using TensorFlow backend.

# %% [markdown]
# **Preparing data**

# %%
df_data = pd.read_csv(DATA_PATH,sep=",",encoding="utf-8").fillna(method='ffill')

class SentenceGetter(object):
    
    def __init__(self, data):
        self.n_sent = 1
        self.data = data
        self.empty = False
        agg_func = lambda s: [(w, t) for w, t in zip(s["TOKEN"].values.tolist(),
                                                           s["TAG"].values.tolist())]
        self.grouped = self.data.groupby("ID").apply(agg_func)
        self.sentences = [s for s in self.grouped]
    
    def get_next(self):
        try:
            s = self.grouped["Sentence: {}".format(self.n_sent)]
            self.n_sent += 1
            return s
        except:
            return None



# Get full document data structure
getter = SentenceGetter(df_data)
# Get sentence data
sentences = [[s[0] for s in sent] for sent in getter.sentences]
# Get TAG labels data
labels = [[s[1] for s in sent] for sent in getter.sentences]
# Convert tag name into index
tags_vals = list(set(df_data["TAG"].values))
# Add X  label for word piece support
# Add [CLS] and [SEP] as BERT need
tags_vals.append('X')
tags_vals.append('[CLS]')
tags_vals.append('[SEP]')
tags_vals = set(tags_vals)
# Manual definition
tag2idx={'C': 2,
 'I': 3,
 'P': 0,
 'Q': 1,
 'W': 4,
 'X':5,
 '[CLS]':6,
 '[SEP]':7}
# Mapping index to name (reverse)
tag2name={tag2idx[key] : key for key in tag2idx.keys()}
# Setup GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
n_gpu = torch.cuda.device_count()
# Vocab
vocabulary = PARENT_DIR + "/data/vocab.txt"
# TODO: Try with increase value
# CAUTION - Should be less than 512
max_len  = 384
# Load tokenizer
# load tokenizer, with manual file address or pretrained address
tokenizer=BertTokenizer(vocab_file=vocabulary,do_lower_case=False)
# TOKENIZER TEXT
tokenized_texts = []
word_piece_labels = []
i_inc = 0
for word_list,label in (zip(sentences, labels)):
    temp_lable = []
    temp_token = []
    
    # Add [CLS] at the front 
    temp_lable.append('[CLS]')
    temp_token.append('[CLS]')
    
    for word,lab in zip(word_list,label):
        token_list = tokenizer.tokenize(word)
        for m,token in enumerate(token_list):
            temp_token.append(token)
            if m==0:
                temp_lable.append(lab)
            else:
                temp_lable.append('X')  
                
    # Add [SEP] at the end
    temp_lable.append('[SEP]')
    temp_token.append('[SEP]')
    
    tokenized_texts.append(temp_token)
    word_piece_labels.append(temp_lable)
    
    if 5 > i_inc:
        print("No.%d,len:%d"%(i_inc,len(temp_token)))
        print("texts:%s"%(" ".join(temp_token)))
        print("No.%d,len:%d"%(i_inc,len(temp_lable)))
        print("lables:%s"%(" ".join(temp_lable)))
    i_inc +=1

# Make text token into id
input_ids = pad_sequences([tokenizer.convert_tokens_to_ids(txt) for txt in tokenized_texts],
                          maxlen=max_len, dtype="long", truncating="post", padding="post")

# Make label into id, pad with "W" meaning others/wrong
# Note - Replaced "O" -> "W" (wrong)
tags = pad_sequences([[tag2idx.get(l) for l in lab] for lab in word_piece_labels],
                     maxlen=max_len, value=tag2idx["W"], padding="post",
                     dtype="long", truncating="post")

# For fine tune of predict, with token mask is 1,pad token is 0
attention_masks = [[int(i>0) for i in ii] for ii in input_ids]

# Since only one sentence, all the segment set to 0
segment_ids = [[0] * len(input_id) for input_id in input_ids]

# Load val set
    
    # Get NER predict result
    logits_prob, _ = torch.max(F.softmax(logits, dim=2),dim=2)
    logits_prob = logits_prob.detach().cpu().numpy()
    # print(logits_prob)
    logits = torch.argmax(F.log_softmax(logits,dim=2),dim=2)
    logits = logits.detach().cpu().numpy()
    
    
    # Get NER true result
    label_ids = label_ids.to('cpu').numpy()
    
    
    # Only predict the real word, mark=0, will not calculate
    input_mask = input_mask.to('cpu').numpy()
    
    # Compare the valuable predict result
    for i,mask in enumerate(input_mask):
        # Real one
        temp_1 = []
        # Predict one
        temp_2 = []

        # Prob one
        prob_temp = []
        
        for j, m in enumerate(mask):
            # Mark=0, meaning its a pad word, dont compare
            if m:
                if tag2name[label_ids[i][j]] != "X" and tag2name[label_ids[i][j]] != "[CLS]" and tag2name[label_ids[i][j]] != "[SEP]" : # Exclude the X label
                    temp_1.append(tag2name[label_ids[i][j]])
                    temp_2.append(tag2name[logits[i][j]])
                    prob_temp.append(logits_prob[i][j])

            else:
                break
        
            
        y_true.append(temp_1)
        y_pred.append(temp_2)
        probs.append(prob_temp)

        

print("f1 socre: %f"%(f1_score(y_true, y_pred)))
print("Accuracy score: %f"%(accuracy_score(y_true, y_pred)))

# Get acc , recall, F1 result report
report = classification_report(y_true, y_pred,digits=4)

# Save the report into file
output_eval_file = EVAL_PATH
with open(output_eval_file, "w") as writer:
    print("***** Eval results *****")
    print("\n%s"%(report))
    print("f1 socre: %f"%(f1_score(y_true, y_pred)))
    print("Accuracy score: %f"%(accuracy_score(y_true, y_pred)))
    
    writer.write("f1 socre:\n")
    writer.write(str(f1_score(y_true, y_pred)))
    writer.write("\n\nAccuracy score:\n")
    writer.write(str(accuracy_score(y_true, y_pred)))
    writer.write("\n\n")  
    writer.write(report)
# Out:
# ***** Running evaluation *****
#   Num examples =953
#   Batch size = 16
# f1 socre: 0.895044
# Accuracy score: 0.988966
# ***** Eval results *****
#
#            precision    recall  f1-score   support
#
#         I     0.8749    0.9472    0.9096     16004
#         C     0.6181    0.6443    0.6310      1417
#         P     0.9113    0.9765    0.9428     12060
#         W     0.7062    0.7125    0.7093      1805
#         Q     0.9920    0.9828    0.9874       756
#
# micro avg     0.8605    0.9324    0.8950     32042
# macro avg     0.8705    0.9324    0.9003     32042
#
# f1 socre: 0.895044
# Accuracy score: 0.988966

# %% [markdown]
# # Write Predictions

# %%
# print(y_true)
# print(y_pred)
# print(probs)
#TODO : Save to csv problem: 2d list
# np.savetxt(PRED_PATH, zip(y_true.flatten(), y_pred.flatten(), probs.flatten()), delimiter=',', fmt='%f')
import pickle
with open(PRED_PATH + "/ytrue_v2", "wb") as f:
  pickle.dump(y_true,f)
with open(PRED_PATH + "/ypred_v2", "wb") as f:
  pickle.dump(y_pred,f)
with open(PRED_PATH + "/probs_v2", "wb") as f:
  pickle.dump(probs,f)

# %%
# !ls "/content/gdrive/My Drive/MultiRC_NER/evaluations"
# Out:
# preds.txt  probs_v2  results.txt  sample_results.txt  ypred_v2	ytrue_v2

# %% [markdown]
# # Analysis
